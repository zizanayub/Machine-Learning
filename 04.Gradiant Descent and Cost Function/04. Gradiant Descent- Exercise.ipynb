# %% [markdown]
# ## 01. Import Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 02. Import and read CSV file

# %%
df = pd.read_csv('04. test_scores.csv')
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %% [markdown]
# ## 03.01. Getting Specific Columns

# %%
df = df.drop('name',axis = 'columns')
df
# Out:
#    math  cs
# 0    92  98
# 1    56  68
# 2    88  81
# 3    70  80
# 4    80  83
# 5    49  52
# 6    65  66
# 7    35  30
# 8    66  68
# 9    67  73

# %% [markdown]
# ## 04. Plotting

# %%
# %matplotlib inline
plt.xlabel('math')
plt.ylabel('cs')
plt.scatter(df.math,df.cs,marker = '+')

# %% [markdown]
# ## 05. Running Linear Regression

# %%
from sklearn import linear_model


predicted_cs = linear_model.LinearRegression()
predicted_cs.fit(df[['math']],df.cs)
# Out:
# LinearRegression()

# %%
predicted_cs.predict([[45]])
# Out:
# C:\Users\sy929\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([47.71335001])

# %% [markdown]
# ## 06. Gradiant Descent Exercise

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline

def gradiant_descent(x,y):
    m_curr = b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.0002
    plt.scatter(x,y,marker = '+',linewidth = 5)

 
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        plt.plot(x,y_predicted,color = 'blue')
    
        md = (-2/n)*sum(x*(y-y_predicted))
        bd = (-2/n)*sum(y-y_predicted)
    
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
    
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
    
    
        print("Coefficient {}, Intercept {},  cost {}, iteration no {}".format(m_curr,b_curr,cost,i))

          
x = np.array(df.math)
y = np.array(df.cs)

gradiant_descent(x,y)
# Out:
# Coefficient 1.9783600000000003, Intercept 0.027960000000000002,  cost 5199.1, iteration no 0
# Coefficient 0.20975041279999962, Intercept 0.0030470367999999894,  cost 4161.482445460163, iteration no 1
# Coefficient 1.7908456142986242, Intercept 0.025401286955264,  cost 3332.2237319269248, iteration no 2
# Coefficient 0.37738163667530467, Intercept 0.005499731626422651,  cost 2669.4843523161976, iteration no 3
# Coefficient 1.6409848166378898, Intercept 0.023373894401807944,  cost 2139.826383775145, iteration no 4
# Coefficient 0.5113514173939655, Intercept 0.0074774305434828076,  cost 1716.5264071567592, iteration no 5
# Coefficient 1.5212165764726306, Intercept 0.021771129698498662,  cost 1378.2272007804495, iteration no 6
# Coefficient 0.6184191426785134, Intercept 0.009075514323270572,  cost 1107.8601808918404, iteration no 7
# Coefficient 1.4254981563597626, Intercept 0.020507724625171385,  cost 891.7842215178443, iteration no 8
# ...
